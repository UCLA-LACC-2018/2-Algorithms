# %% [markdown]
# # Non-decreasing List
# Given a list with n integers, your task is to check if it could become non-decreasing by modifying at most 1 element.
# We define a list is non-decreasing if list[i] <= list[i + 1] holds for every i (0 <= i < n-2).
# ### Example 1:
# Input: [4,2,3]<br>
# Output: True<br>
# Explanation: You could modify the first 4 to 1 to get a non-decreasing array.
# ### Example 2:
# Input: [4,2,1]<br>
# Output: False<br>
# Explanation: You can't get a non-decreasing array by modify at most one element.
#
# Note: The n belongs to [1, 10,000].<br>
#
# _Adapted from LeetCode_

# %%
# Test data loading
import pickle

with open ('./NDL_test_data', 'rb') as fp:
    test_data = pickle.load(fp)

# %% [markdown]
# Your list-checking function

# %%
def checkPossibility(nums):
    """
    :type nums: List[int]
    :return type: bool
    """
    #Modify this function
    
    return True

# %% [markdown]
# Test your function by running the code below

# %%
import time
correct = 0
total = 0
start_time = time.time()
for test_vector in test_data:
    test_list = test_vector[0].copy()
    true_result = test_vector[1]
    test_result = checkPossibility(test_vector[0])
    if test_result == true_result:
        correct +=1
    else:
        print("List under test is: " + str(test_list) + ". Correct result is: " + str(true_result) + ". Your result is: " + str(test_result))
    total +=1
end_time = time.time()
print("%i/%i test cases passed" %(correct, total))
print("Total time taken is %.6fseconds" %(end_time-start_time))
# Out:
# List under test is: [13, 11, 1]. Correct result is: False. Your result is: True
# List under test is: [12, 8, 5]. Correct result is: False. Your result is: True
# List under test is: [14, 9, 4]. Correct result is: False. Your result is: True
# List under test is: [10, 8, 5]. Correct result is: False. Your result is: True
# List under test is: [13, 10, 0]. Correct result is: False. Your result is: True
# List under test is: [15, 9, 1]. Correct result is: False. Your result is: True
# List under test is: [11, 6, 0]. Correct result is: False. Your result is: True
# List under test is: [12, 9, 7]. Correct result is: False. Your result is: True
# List under test is: [12, 4, 1]. Correct result is: False. Your result is: True
# List under test is: [8, 2, 0]. Correct result is: False. Your result is: True
# List under test is: [14, 12, 1]. Correct result is: False. Your result is: True
# List under test is: [10, 8, 6]. Correct result is: False. Your result is: True
# List under test is: [14, 8, 0]. Correct result is: False. Your result is: True
# List under test is: [9, 5, 4]. Correct result is: False. Your result is: True
# List under test is: [14, 13, 9]. Correct result is: False. Your result is: True
# List under test is: [8, 7, 3]. Correct result is: False. Your result is: True
# List under test is: [15, 11, 0]. Correct result is: False. Your result is: True
# List under test is: [13, 5, 4]. Correct result is: False. Your result is: True
# List under test is: [14, 10, 6]. Correct result is: False. Your result is: True
# List under test is: [5, 3, 0]. Correct result is: False. Your result is: True
# List under test is: [9, 8, 4]. Correct result is: False. Your result is: True
# List under test is: [12, 9, 1]. Correct result is: False. Your result is: True
# List under test is: [12, 11, 0]. Correct result is: False. Your result is: True
# List under test is: [12, 1, 0]. Correct result is: False. Your result is: True
# List under test is: [11, 8, 6]. Correct result is: False. Your result is: True
# List under test is: [9, 3, 2]. Correct result is: False. Your result is: True
# List under test is: [6, 13, 8, 7]. Correct result is: False. Your result is: True
# List under test is: [4, 2, 10, 1]. Correct result is: False. Your result is: True
# List under test is: [3, 2, 15, 8]. Correct result is: False. Your result is: True
# List under test is: [12, 6, 10, 3]. Correct result is: False. Your result is: True
# List under test is: [7, 13, 2, 1]. Correct result is: False. Your result is: True
# List under test is: [8, 2, 1, 15]. Correct result is: False. Your result is: True
# List under test is: [14, 0, 15, 11]. Correct result is: False. Your result is: True
# List under test is: [10, 2, 12, 6]. Correct result is: False. Your result is: True
# List under test is: [15, 15, 11, 8]. Correct result is: False. Your result is: True
# List under test is: [1, 14, 0, 5]. Correct result is: False. Your result is: True
# List under test is: [11, 3, 2, 1]. Correct result is: False. Your result is: True
# List under test is: [8, 14, 7, 7]. Correct result is: False. Your result is: True
# List under test is: [2, 7, 4, 3]. Correct result is: False. Your result is: True
# List under test is: [10, 6, 7, 2]. Correct result is: False. Your result is: True
# List under test is: [14, 14, 12, 13]. Correct result is: False. Your result is: True
# List under test is: [15, 4, 9, 0]. Correct result is: False. Your result is: True
# List under test is: [11, 6, 5, 8]. Correct result is: False. Your result is: True
# List under test is: [1, 13, 10, 0]. Correct result is: False. Your result is: True
# List under test is: [11, 15, 1, 1]. Correct result is: False. Your result is: True
# List under test is: [11, 15, 9, 4]. Correct result is: False. Your result is: True
# List under test is: [7, 10, 9, 4]. Correct result is: False. Your result is: True
# List under test is: [14, 8, 7, 13]. Correct result is: False. Your result is: True
# List under test is: [12, 12, 9, 1]. Correct result is: False. Your result is: True
# List under test is: [2, 13, 12, 0]. Correct result is: False. Your result is: True
# List under test is: [14, 14, 11, 4, 10]. Correct result is: False. Your result is: True
# List under test is: [2, 4, 3, 1, 6]. Correct result is: False. Your result is: True
# List under test is: [3, 5, 2, 13, 2]. Correct result is: False. Your result is: True
# List under test is: [2, 5, 11, 8, 4]. Correct result is: False. Your result is: True
# List under test is: [7, 2, 11, 10, 8]. Correct result is: False. Your result is: True
# List under test is: [6, 0, 11, 14, 5]. Correct result is: False. Your result is: True
# List under test is: [15, 0, 11, 14, 3]. Correct result is: False. Your result is: True
# List under test is: [7, 2, 14, 13, 0]. Correct result is: False. Your result is: True
# List under test is: [6, 14, 11, 8, 11]. Correct result is: False. Your result is: True
# List under test is: [11, 3, 1, 9, 4]. Correct result is: False. Your result is: True
# List under test is: [8, 15, 4, 8, 9]. Correct result is: False. Your result is: True
# List under test is: [5, 4, 12, 0, 8]. Correct result is: False. Your result is: True
# List under test is: [13, 11, 15, 1, 4]. Correct result is: False. Your result is: True
# List under test is: [5, 12, 1, 5, 4]. Correct result is: False. Your result is: True
# List under test is: [11, 8, 9, 8, 11]. Correct result is: False. Your result is: True
# List under test is: [14, 0, 15, 6, 14]. Correct result is: False. Your result is: True
# List under test is: [10, 9, 3, 7, 1]. Correct result is: False. Your result is: True
# List under test is: [6, 14, 4, 8, 1]. Correct result is: False. Your result is: True
# List under test is: [12, 3, 10, 10, 2]. Correct result is: False. Your result is: True
# List under test is: [10, 2, 2, 12, 5]. Correct result is: False. Your result is: True
# List under test is: [1, 12, 10, 4, 14]. Correct result is: False. Your result is: True
# List under test is: [11, 4, 2, 2, 14]. Correct result is: False. Your result is: True
# List under test is: [9, 8, 7, 2, 0]. Correct result is: False. Your result is: True
# List under test is: [6, 15, 4, 13, 6]. Correct result is: False. Your result is: True
# List under test is: [12, 7, 11, 3, 2]. Correct result is: False. Your result is: True
# List under test is: [6, 12, 6, 12, 1]. Correct result is: False. Your result is: True
# List under test is: [7, 2, 3, 14, 10, 5]. Correct result is: False. Your result is: True
# List under test is: [12, 12, 12, 1, 8, 3]. Correct result is: False. Your result is: True
# List under test is: [0, 12, 6, 8, 7, 3]. Correct result is: False. Your result is: True
# List under test is: [1, 3, 10, 0, 15, 9]. Correct result is: False. Your result is: True
# List under test is: [15, 6, 11, 2, 3, 15]. Correct result is: False. Your result is: True
# List under test is: [9, 5, 2, 4, 14, 15]. Correct result is: False. Your result is: True
# List under test is: [12, 10, 15, 9, 11, 15]. Correct result is: False. Your result is: True
# List under test is: [11, 11, 6, 14, 7, 1]. Correct result is: False. Your result is: True
# List under test is: [4, 13, 3, 8, 2, 11]. Correct result is: False. Your result is: True
# List under test is: [11, 6, 2, 7, 11, 4]. Correct result is: False. Your result is: True
# List under test is: [7, 4, 5, 11, 14, 6]. Correct result is: False. Your result is: True
# List under test is: [12, 3, 6, 5, 11, 15]. Correct result is: False. Your result is: True
# List under test is: [8, 9, 5, 4, 8, 3]. Correct result is: False. Your result is: True
# List under test is: [9, 2, 6, 14, 4, 6]. Correct result is: False. Your result is: True
# List under test is: [6, 10, 2, 15, 0, 10]. Correct result is: False. Your result is: True
# List under test is: [1, 7, 1, 7, 6, 4]. Correct result is: False. Your result is: True
# List under test is: [8, 2, 7, 4, 11, 0]. Correct result is: False. Your result is: True
# List under test is: [15, 6, 3, 7, 14, 12]. Correct result is: False. Your result is: True
# List under test is: [12, 11, 11, 0, 11, 4]. Correct result is: False. Your result is: True
# List under test is: [11, 8, 1, 5, 5, 10]. Correct result is: False. Your result is: True
# List under test is: [3, 6, 9, 4, 6, 2]. Correct result is: False. Your result is: True
# List under test is: [11, 1, 8, 5, 15, 14]. Correct result is: False. Your result is: True
# List under test is: [12, 7, 9, 5, 9, 2]. Correct result is: False. Your result is: True
# List under test is: [4, 11, 10, 0, 4, 3]. Correct result is: False. Your result is: True
# List under test is: [12, 14, 0, 10, 4, 4]. Correct result is: False. Your result is: True
# List under test is: [0, 4, 1, 8, 2, 1]. Correct result is: False. Your result is: True
# List under test is: [3, 15, 10, 5, 3, 5]. Correct result is: False. Your result is: True
# List under test is: [2, 15, 11, 0, 5, 15]. Correct result is: False. Your result is: True
# List under test is: [6, 0, 6, 0, 0, 12, 7]. Correct result is: False. Your result is: True
# List under test is: [2, 10, 1, 9, 0, 5, 9]. Correct result is: False. Your result is: True
# List under test is: [10, 5, 0, 13, 2, 9, 5]. Correct result is: False. Your result is: True
# List under test is: [13, 5, 10, 12, 2, 5, 8]. Correct result is: False. Your result is: True
# List under test is: [15, 0, 7, 2, 1, 13, 6]. Correct result is: False. Your result is: True
# List under test is: [11, 0, 5, 9, 2, 15, 11]. Correct result is: False. Your result is: True
# List under test is: [7, 2, 12, 7, 15, 6, 8]. Correct result is: False. Your result is: True
# List under test is: [11, 14, 6, 2, 15, 9, 12]. Correct result is: False. Your result is: True
# List under test is: [13, 11, 5, 4, 5, 3, 4]. Correct result is: False. Your result is: True
# List under test is: [13, 6, 15, 13, 5, 5, 10]. Correct result is: False. Your result is: True
# List under test is: [13, 0, 2, 7, 1, 10, 6]. Correct result is: False. Your result is: True
# List under test is: [12, 4, 7, 0, 2, 1, 14]. Correct result is: False. Your result is: True
# List under test is: [4, 8, 6, 6, 11, 13, 0]. Correct result is: False. Your result is: True
# List under test is: [7, 10, 5, 3, 3, 8, 1]. Correct result is: False. Your result is: True
# List under test is: [11, 13, 9, 9, 15, 14, 0]. Correct result is: False. Your result is: True
# List under test is: [6, 10, 12, 6, 2, 11, 13]. Correct result is: False. Your result is: True
# List under test is: [6, 15, 13, 0, 10, 15, 0]. Correct result is: False. Your result is: True
# List under test is: [4, 2, 13, 12, 1, 10, 10]. Correct result is: False. Your result is: True
# List under test is: [15, 5, 12, 15, 6, 12, 11]. Correct result is: False. Your result is: True
# List under test is: [5, 8, 10, 13, 12, 11, 15]. Correct result is: False. Your result is: True
# 126/250 test cases passed
# Total time taken is 0.057036seconds
